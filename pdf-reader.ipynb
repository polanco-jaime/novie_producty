# %%
# Specify the directory path where your PDF files are located
directory_path = './Papers American Economic Review/Paper 3 - Test/'

papers_summarization_to_word(directory_path, 'docs')
# Out:
# I will read 2 papers
# The paper 1-s2.0-S0047272722001311-main.pdf is being reading
# The paper park2018.pdf is being reading
# I got 2 summarization of 2 papers
# The summarization of articles had finished successfully.

# %%
# pip install pdfminer.six
# !pip install reportlab

# %%
# # pip install pdfminer.six
# # !pip install sentence-transformers
# # Install modules
# !pip install google-cloud-aiplatform --upgrade --user "shapely<2.0.0"

# !pip install typing-extensions
# !pip install google-cloud-documentai

# !pip install pdf2image
# !apt-get install poppler-utils
# !pip install gradio

# %% [markdown]
# # Section of dependences

# %%
from pdfminer.high_level import extract_text
from sentence_transformers import SentenceTransformer, CrossEncoder, util
import vertexai
from vertexai.language_models import TextGenerationModel
# !gcloud auth application-default login
# !pip install python-docx
import unicodedata
import vertexai
from vertexai.language_models import TextGenerationModel
from docx import Document
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
from docx import Document
from docx.enum.text import WD_BREAK
import os
from docx import Document
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.pagesizes import letter, landscape
from reportlab.platypus import SimpleDocTemplate, Paragraph, PageBreak
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer  # Import Spacer
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, PageBreak  # Import PageBreak
from reportlab.platypus import SimpleDocTemplate, PageBreak, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet

vertexai.init(project="lee-javeriana", location="us-central1")
# def text_correction(texto):
#     parameters = {    "max_output_tokens": 1024, }
#     model = TextGenerationModel.from_pretrained("text-bison@001")
#     promt_text_correctoion= """The next text came from a scientific paper in pdf that has been read in Python, can you correct the text to be fluent and clear?\n"""
#     promt_text_correctoion += "input_text: '"+ texto +  "' \n output_text: " 
#     response = model.predict(promt_text_correctoion  ,    **parameters )
#     return response.text


def extract_cleaned_paragraphs(pdf_file_path, starting_index=800, step_size=1200, window_size=1400):
    # Extract text from PDF
    text = extract_text(pdf_file_path, codec = 'utf-8')
    #     # Remove hyphens at the end of lines
    text = text.replace('-\n', '').replace('abuse', 'imposition').replace('¨o', 'o').replace('´', '')
    
#     # Normalize special characters using unicodedata
#     normalized_text = unicodedata.normalize('NFKC', text).encode('ASCII', 'ignore').decode('ASCII')
    
    # Tokenize the normalized text
    text_tokens = text.split()
    
    # Prepare paragraphs
    sentences = []
    sentences.append(text_tokens[:starting_index])
    
    for i in range(starting_index, len(text_tokens), step_size):
        window = text_tokens[i : i + window_size]
        if len(window) < window_size:
            break
        sentences.append(window)
    
    paragraphs = [" ".join(s) for s in sentences]
    return paragraphs
    
def promt_desing(texto):
    promt =     """Use the following pieces of context to summarize the article, Don't use external information, and Don't invent or make up things.Get an answer for each of the next points.

1. Paper title
2. Year
3. Abstract summary
4. Authors
5. Journal
6. Number of participants
7. Population characteristics
8. Intervention
9. Main findings
10. Outcomes measured
11. Design of the Study
12. Research Problem  

EXAMPLE 1.
input_text: \'Black Gold and Dull Minds: The Impact of Question research: Hydrocarbon Exploration Announcements on Education in Colombia ∗ Polanco-Jimenez, Jaime† Christian Posso‡ July 23, 2023 Abstract This study investigates the impact of the shocks in expected income resulting from the announcement of a hydrocarbon exploration on dropout rates in schools within the exploration areas of Colombia. Employing a Geographic Regression Discontinuity Design, we capture the local impact of exploration announcements and establish a causal relationship. Our findings reveal a significant reduction in dropout rates among elementary school pupils, with a more pronounced effect observed among girls. However, an increase in dropout rates is observed among secondary school pupils. These results highlight the complex and nuanced relationship between natural resources and educational outcomes, suggesting the presence of underlying factors influencing dropout rates at different stages of schooling. These findings underscore the critical importance of incorporating the impact of expected income shocks in educational policy formulation, particularly within exploration and explotaition of natural resources areas. JEL Codes: I21, O13. Key Words: oil and gas exploration, education, human capital accumulation, labor force, ∗We thank Gloria Bernal and Oliver Pardo for his relentless supervision and support. Thanks to Brigitte Castaneda, Luz Abadia And Omar Garzon for their suggestions, and support and for providing valuable elements that allowed this project to be carried out. †PhD Student in Economics, Pontifical Xavierian University, jaime.polanco@javeriana.edu.co, Corresponding Author. This paper corresponds to my Job Market Paper. ‡Researcher at Banco de la Republica de Colombia, cpossosu@banrep.gov.co 1 1 Introduction The relationship between economic activities and educational outcomes has been a topic of significant interest in the field of economics. Understanding how different economic sectors influence educational outcomes is crucial for policymakers and researchers alike. In the context of Colombia, a country with a long history of oil and gas production, exploring the impact of hydrocarbon exploration on dropout rates and academic performance is particularly relevant. Colombia has substantial dependence on hydrocarbon resources, which constitute a significant portion of its export earnings and government revenues, highlighting the need to comprehensively examine the consequences of oil price fluctuations and demand shocks on the educational sector. Research conducted by Quintero Otero (2020) reveals that oil price dynamics resulting from specific demand shocks can lead to substantial cumulative impacts on the country’s Gross Domestic Product (GDP), underscoring the significant economic implications for educational outcomes. In Colombia, the National Hydrocarbons Agency (ANH) plays a pivotal role in regulating the oil and gas industry.   \' 
output_text = {
1. Paper title: Black Gold and Dull Minds: The Impact of Hydrocarbon Exploration Announcements on Education in Colombia
2. Year: 2023
3. Abstract summary: This study examines the effect of expected income shocks resulting from hydrocarbon exploration announcements on dropout rates in Colombian schools. Using a Geographic Regression Discontinuity Design, the study finds that there is a significant reduction in dropout rates among elementary school students, especially girls, while an increase is observed among secondary school students. This suggests a complex relationship between natural resources and educational outcomes, emphasizing the need to consider income shocks in educational policy within resource exploration areas.
4. Authors: Polanco-Jimenez, Jaime; Christian Posso
5. Journal: Not provided in the given text.
6. Number of participants: Schools within hydrocarbon exploration areas of Colombia (number not specified in the provided text).
7. Population characteristics: Students in schools located within hydrocarbon exploration areas of Colombia.
8. Intervention: The study focuses on the impact of hydrocarbon exploration announcements on expected income changes and subsequent decision-making among students attending schools in exploration areas.
9. Main findings: The study shows a significant reduction in dropout rates among elementary school students, particularly girls, after hydrocarbon exploration announcements. However, secondary school students experienced an increase in dropout rates. This highlights a nuanced relationship between natural resource exploration and education outcomes.
10. Outcomes measured: Dropout rates in elementary and secondary schools in hydrocarbon exploration areas of Colombia.
11. Design of the Study: Geographic Regression Discontinuity Design was employed to capture the local impact of exploration announcements and establish a causal relationship.
12. Research Problem: What is the impact of hydrocarbon exploration announcements on dropout rates in schools within the exploration areas of Colombia?
}
 
EXAMPLE 2.
input_text: \Effect of a consultation teaching behavior modification on sleep performance in pupils: a randomized controlled trial Brian G Symon, John E Marley, A James Martin and Emily R Norman U p to 46% of parents report newborns sleep problems.1-5 These include not sleeping through the night, delay in achieving sleep, and atypical behaviour at wakening. These sleep disturbances may have serious negative consequences, including postnatal depression. Disturbances may be long-lasting, with one study finding that, based on parental reports, 41% of children with sleeping disturbance at 8 months still had difficulties at 3 years.7 Studies of sleep achievement show that all individuals, including babies, “learn” to fall asleep with certain external environmental The Medical Journal of Australia ISSN: cues.1,8,9 Sleep initiation is repeated several 0025-729X 7 March 2005 182 5 215-218 times during the night, as all individuals ©The Medical Journal of Australia 2005 repeatedly awaken for brief periods. Howwww.mja.com.au Research ever, these awakenings and returns to sleep are usually not understood by parents. It has been suggested that parents can inadvertently contribute to unwelcome night crying when they rock, hold, pat or feed their newborns to sleep. The child may learn to re-initiate sleep repeatedly by signalling (crying) for the parent to repeat similar behaviours.10 Techniques of resolving sleep problems in newbornsand young children that have shown the best and most persistent results involve behaviour modificatio \' 
output_text = {
1. Paper title: Effect of a consultation teaching behavior modification on sleep performance in pupils: a randomized controlled trial
2. Year: Not specified in the given text.
3. Abstract summary: A randomized controlled trial was conducted to determine the effectiveness of a consultation teaching behaviour modification program in improving sleep performance in newborns. The intervention group (n = 40) received a consultation teaching behaviour modification program, while the control group (n = 40) received a standard care control. The primary outcome was the number of nights per week that the infant slept for 5 hours or more. The secondary outcomes were the number of nights per week that the infant cried for 30 minutes or more, the number of nights per week that the infant woke up more than 3 times, and the number of nights per week that the infant woke up before 6 am. The intervention group had significantly more nights per week that the infant slept for 5 hours or more (mean difference 1.5, 95% confidence interval 0.6-2.4, P = 0.005) and fewer nights per week that the infant cried for 30 minutes or more (mean difference 0.6, 95% confidence interval 0.1-1.1, P = 0.02). There were no significant differences between the groups for the number of nights per week that the infant woke up more than 3 times or the number of nights per week that the infant woke up before 6 am.
4. Authors: Brian G Symon, John E Marley, A James Martin and Emily R Norman
5. Journal: The Medical Journal of Australia
6. Number of participants: 80
7. Population characteristics: Newborns
8. Intervention: Consultation teaching behavior modification program
9. Main findings: The intervention group had significantly more nights per week that the infant slept for 5 hours or more and fewer nights per week that the infant cried for 30 minutes or more.
10. Outcomes measured: The number of nights per week that the infant slept for 5 hours or more, the number of nights per week that the infant cried for 30 minutes or more, the number of nights per week that the infant woke up more than 3 times, and the number of nights per week that the infant woke up before 6 am.
11. Design of the Study: Randomized controlled trial
12. Research Problem: What is the effect of a consultation teaching behavior modification on sleep performance in pupils?
}
\ END

input_text: \'"""
    promt+= texto
    promt+=    """ \'   \n 
output_text:
""" 
    return promt
# # ------------------------------------
# def create_word_document(Resultado, output_filename):
#     # Create a new Document
#     doc = Document()

#     for result in Resultado:
#         sections = result.split('\n')

#         # Create a new page for each result
#         doc.add_page_break()

#         for section in sections:
#             parts = section.split(': ', 1)
#             if len(parts) == 2:
#                 title = parts[0]
#                 content = parts[1]
                
#                 # Add title as a bold paragraph
#                 title_paragraph = doc.add_paragraph()
#                 title_paragraph.add_run(f'{title}: ').bold = True
#                 title_paragraph.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

#                 # Add content as a paragraph
#                 content_paragraph = doc.add_paragraph(content)

#     # Save the document
#     doc.save(output_filename)

def create_word_document(analysis, Resultado, output_filename):
    # Create a new Document  
    doc = Document()

    # Add general abstract as first paragraph
    abstract_paragraph = doc.add_paragraph(analysis)

    for result in Resultado:

        sections = result.split('\n')

        # Create a new page for each result  
        doc.add_page_break()

        for section in sections:
            parts = section.split(': ', 1)  

            if len(parts) == 2:
                title = parts[0]
                content = parts[1]

                # Add title as a bold paragraph
                title_paragraph = doc.add_paragraph()  
                title_paragraph.add_run(f'{title}: ').bold = True
                title_paragraph.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

                # Add content as a paragraph
                content_paragraph = doc.add_paragraph(content)

    # Save the document
    doc.save(output_filename)

# def create_pdf_document(Resultado, output_filename):
#     # Create a list to hold the PDF content
#     pdf_content = []

#     # Define styles for the PDF content
#     styles = getSampleStyleSheet()

#     for i, result in enumerate(Resultado):
#         # Add a page break before each result (except the first one)
#         if i != 0:
#             pdf_content.append(PageBreak())

#         sections = result.split('\n')

#         for section in sections:
#             parts = section.split(': ', 1)
#             if len(parts) == 2:
#                 title = parts[0]
#                 content = parts[1]

#                 # Add title as a heading
#                 pdf_content.append(Paragraph(f'<font size="14"><b>{title}:</b></font>', styles['Heading1']))

#                 # Add content as body text
#                 pdf_content.append(Paragraph(content, styles['Normal']))

#     # Create a PDF using SimpleDocTemplate
#     doc = SimpleDocTemplate(output_filename, pagesize=letter)
#     doc.build(pdf_content)

def create_pdf_document(analysis, Resultado, output_filename):

    pdf_content = []

    styles = getSampleStyleSheet()

    # Add abstract as first element 
    pdf_content.append(Paragraph(analysis, styles['Normal'])) 
    pdf_content.append(Spacer(1, 12))

    for i, result in enumerate(Resultado):

        if i != 0:
            pdf_content.append(PageBreak())

        sections = result.split('\n')

        for section in sections:

            parts = section.split(': ', 1)  

            if len(parts) == 2:

                title = parts[0]
                content = parts[1]

                # Add title as heading
                pdf_content.append(Paragraph(f'<font size="14"><b>{title}:</b></font>', styles['Heading1']))

                # Add content 
                pdf_content.append(Paragraph(content, styles['Normal']))

    # Create PDF
    doc = SimpleDocTemplate(output_filename, pagesize=letter)
    doc.build(pdf_content)
    
    
def promt_analysis(text = "", question_of_interest = ""):
    promt_analysis = """ 
    
    Example. 
input_text: "Give me an opinion of the next literature review. Please use only the information that is below. Dont incluede additional information. Use formal tone and an academic language.  When mentioning an article, you must name the author's last name and the year of the article (Example: Last Name Author, Year).
summarizations: {
1. Paper title: Environmental Regulation and Green Skills: An Empirical Exploration
2. Abstract summary: This paper provides new evidence on the workplace skills most relevant in the transition toward environmentally sustainable economies. Using a novel data-driven methodology, the authors identify two main sets of green skills, namely, engineering skills for the design and production of technology, and managerial skills for implementing and monitoring environmental organizational practices. Exploiting exogenous geographical variation in regulatory stringency, the authors also evaluate the effect of environmental regulation on the demand of green skills for a panel of US metropolitan and nonmetropolitan areas over the period 2006–14. The main finding is that while these changes in environmental regulation have no impact on overall employment, they create significant, if modest, gaps in the demand for some green skills, especially those related to technical and engineering work tasks.
3. Authors: Francesco Vona, Giovanni Marin, Davide Consoli, David Popp
4. Journal: Journal of the Association of Environmental and Resource Economists
5. Number of participants: Not specified in the given text.
6. Population characteristics: Not specified in the given text.
7. Intervention: Not specified in the given text.
8. Main findings: The authors find that environmental regulation has no impact on overall employment, but it does create significant, if modest, gaps in the demand for some green skills, especially those related to technical and engineering work tasks.
9. Outcomes measured: Not specified in the given text.
10. Design of the Study: Not specified in the given text.
11. Year: 2018
12. Research Problem:What is the impact of environmental regulation on the demand for specific green skills, particularly those related to technical and engineering work tasks, during the transition towards environmentally sustainable economies?
}
{
1. Paper title: A GREENER LABOR MARKET: EMPLOYMENT, POLICIES, AND ECONOMIC TRANSFORMATION
2. Abstract summary: The green economic transformation needed to achieve net zero emissions will also require changes in employment. This chapter examines the labor market implications of this transition, using a mix of empirical and model-based analyses. Looking at a sample of largely advanced economies, the empirical analysis indicates that both greener and more polluting jobs are concentrated among small subsets of workers. Individual workers face tough challenges in moving to greener jobs from more pollution-intensive jobs, complicating labor reallocation. Higher skills make job transitions easier, highlighting the potential importance of training. Stronger environmental policies help green the labor market and appear more effective when reallocation incentives are not blunted. Finally, a policy package incorporating a green infrastructure push, phased-in carbon prices, and targeted training and an earned income tax credit to provide income support and incentivize labor supply could put an economy on a path to net zero emissions by 2050, with an inclusive transition. Model simulations for a representative advanced economy suggest that about 1 percent of employment would shift toward greener activities over a 10-year period. By contrast, for a representative emerging market economy, about 2.5 percent of employment would shift, reflecting differences in workforce skills and greater reliance on higher-emissions-intensive production. Delays in policy actions will require sharper labor market adjustments to achieve net zero emissions.
3. Authors: John Bluedorn (co-lead), Niels-Jakob Hansen (co-lead), Diaa Noureldin, Ippei Shibata, and Marina M. Tavares, with support from Savannah Newman and Cynthia Nyakeri.
4. Journal: World Economic Outlook
5. Number of participants: Not specified in the given text.
6. Population characteristics: Workers in largely advanced economies.
7. Intervention: Green infrastructure push, phased-in carbon prices, and targeted training and an earned income tax credit.
8. Main findings: The green economic transformation will require changes in employment, with both greener and more polluting jobs concentrated among small subsets of workers. Individual workers face tough challenges in moving to greener jobs from more pollution-intensive jobs, complicating labor reallocation. Higher skills make job transitions easier, highlighting the potential importance of training. Stronger environmental policies help green the labor market and appear more effective when reallocation incentives are not blunted. Finally, a policy package incorporating a green infrastructure push, phased-in carbon prices, and targeted training and an earned income tax credit to provide income support and incentivize labor supply could put an economy on a path to net zero emissions by 2050, with an inclusive transition.
9. Outcomes measured: Not specified in the given text.
10. Design of the Study: Cross-country, harmonized set of indicators of the environmental properties of jobs, built in part on earlier single-country studies; and a new model-based analysis of labor reallocation in the green transition with an expanded set of policy instruments.
11. Year: 2021
12. Research Problem:What happens to jobs during the shift to a greener economy, and how can we help workers transition to environmentally friendly jobs while achieving net zero emissions?
}"

output_text: "The reviewed literature presents two distinct papers that contribute to the understanding of the relationship between environmental considerations and the labor market. Both papers explore the intricate interplay between environmental regulations, employment dynamics, and the skills required for a sustainable economic transformation.

The paper titled "Environmental Regulation and Green Skills: An Empirical Exploration" by Vona, Marin, Consoli, and Popp (Year) investigates the impact of environmental regulations on the demand for specific skills within the workforce. The authors employ a novel data-driven methodology to identify two primary categories of green skills: engineering skills for technological design and production, and managerial skills for the implementation and monitoring of environmentally conscious practices. Through a thorough evaluation of regulatory stringency, the study unveils the effect of environmental regulations on the demand for green skills across US metropolitan and nonmetropolitan areas. The main finding underscores that while these regulations do not influence overall employment levels, they do create notable disparities in the demand for certain green skills, particularly those associated with technical and engineering tasks.

The second paper, "A GREENER LABOR MARKET: EMPLOYMENT, POLICIES, AND ECONOMIC TRANSFORMATION" by Bluedorn, Hansen, Noureldin, Shibata, Tavares, Newman, and Nyakeri (Year), delves into the labor market implications of the essential shift towards a greener economy to achieve net zero emissions. Drawing upon a combination of empirical analyses and model-based simulations, the authors assess the challenges and opportunities posed by this transformation. They reveal that the labor market is marked by a concentration of both greener and more polluting jobs within specific worker subsets. The transition from pollution-intensive jobs to greener alternatives is complex, accentuating the need for effective training and skill enhancement. Furthermore, the paper highlights the influence of environmental policies on the labor market's transition. It suggests that policy interventions such as a green infrastructure push, phased-in carbon prices, targeted training, and an earned income tax credit can lead to a labor market aligned with sustainability goals. The study's findings are supported by model simulations that predict shifts in employment distribution based on the level of economic development and workforce skills.

In summary, the examined literature provides valuable insights into the relationship between environmental concerns and labor market dynamics. The papers collectively emphasize the critical role of skills and policy interventions in facilitating the transition to a sustainable economy while navigating challenges posed by environmental regulations and the complex restructuring of the labor market. The findings from these studies contribute to the discourse on achieving economic transformation while addressing environmental imperatives and ensuring equitable labor market outcomes."
END \n
"""
    if question_of_interest != "":
        promt_analysis += """Give me an opinion of the next literature review answering to the question: {}.
    Please use only the information that is below. Dont incluede additional information. Use formal tone and an academic language.  When mentioning an article, you must name the author's last name and the year of the article (Example: Last Name Author, Year).
    summarizations: '{}' \n
    """.format(question_of_interest, text)
    else:
        promt_analysis += """Give me an opinion of the next literature review. Incluede in your opinion incluede all literature provided. Please use only the information that is below. Dont incluede additional information. Use formal tone and an academic language.  When mentioning an article, you must name the author's last name and the year of the article (Example: Last Name Author, Year).
    summarizations:  '{}' \n
    """.format( text)
    promt_analysis += "output_text: "
 
    return promt_analysis

def papers_summarization_to_word(directory_path, output_file = 'docs'):
    # List all files in the directory
    all_files = os.listdir(directory_path)

    # Filter the PDF files
    # pdf_files = [file for file in all_files if file.endswith('.pdf')]
    pdf_files = [file for file in all_files if file.endswith('.pdf') and file != 'paper_summarization.pdf']



    print("I will read {} papers".format(len(pdf_files)) )
    try:
        Respuesta=[]
        # Print the list of PDF files
        for pdf_file in pdf_files:
            print("The paper {} is being reading".format(pdf_file) )
            paragraphs = extract_cleaned_paragraphs('./'+directory_path+pdf_file)
            texto  = paragraphs[0]
            promt = promt_desing(texto)
            try:
                response = model.predict(promt ,    **parameters )
                Respuesta.append(response.text )
            except:
                print("Error reading the paper {}".format(pdf_file) )

        print("I got {} summarization of {} papers".format(len(Respuesta), len(pdf_files)) )

        Respuesta = [item for item in Respuesta if item != ""]
        combined_string = '\n'.join(Respuesta)
        # Your loop processing code for each paragraph
        analysis = model.predict(promt_analysis(combined_string) ,    **parameters ).text 



        # Create a new Document
        if 'doc' in output_file.lower():
            create_word_document(analysis, Respuesta, directory_path+'/paper_summarization.docx')
        elif output_file == 'pdf':
            create_pdf_document(analysis, Respuesta, directory_path+'/paper_summarization.pdf')

        print("The summarization of articles had finished successfully.")
    except Exception as e:
        print(e)

# %% [markdown]
# # Section of split text

# %% [markdown]
# ## Vertex text bison simple setting

# %%
import vertexai
from vertexai.language_models import TextGenerationModel

vertexai.init(project="ph-jabri", location="us-central1")
parameters = {
    "temperature":0.2,
    "max_output_tokens": 1024,
    "top_p": 0.9,
    "top_k": 40
}
model = TextGenerationModel.from_pretrained("text-bison@001")

# %% [markdown]
# # Test analysis

# %%
# model.predict(promt ,    **parameters ).text 
# print(promt)

# %%
# directory_path = './Papers American Economic Review/Paper 2 - K De Witte/'
# pdf_files = [file for file in all_files if file.endswith('.pdf') and file != 'paper_summarization.pdf']

# Respuesta=[]
# # Print the list of PDF files
# for pdf_file in pdf_files:
#     print("The paper {} is being reading".format(pdf_file) )
#     paragraphs = extract_cleaned_paragraphs('./'+directory_path+pdf_file)
#     texto  = paragraphs[0]
#     promt = promt_desing(texto)
#     try:
#         response = model.predict(promt ,    **parameters )
#         Respuesta.append(response.text )
#     except:
#         print("Error reading the paper {}".format(pdf_file) )

# %%
len(Respuesta)
# Out:
# 7

# %%
# step = 4
# General_analysis = []


# # for i in range(0, len(Respuesta), step):
# #     batch = Respuesta[i:i+step]
# #     for research in batch:
# #         # Join the list elements into a single string
# #         combined_string = '\n'.join(research)
# #         # Your loop processing code for each paragraph
# #         analysis = model.predict(promt_analysis(combined_string) ,    **parameters ).text 
# #         General_analysis.append(analysis )
 
# #     print("==== End of Batch ====")
    
# Respuesta = [item for item in Respuesta if item != ""]
# combined_string = '\n'.join(Respuesta)
# # Your loop processing code for each paragraph
# analysis = model.predict(promt_analysis(combined_string) ,    **parameters ).text 
# print(analysis)

# %%
# combined_string

# %% [markdown]
# # Ejemplo Bri

# %%
# Specify the directory path where your PDF files are located
directory_path = './Test Papers Brigitte Castaneda/'

# papers_summarization_to_word(directory_path, 'docs')
# papers_summarization_to_word(directory_path + "Argentina/", 'docs')
papers_summarization_to_word(directory_path + "Colombia/", 'docs')
# papers_summarization_to_word(directory_path + "India/", 'docs')
# papers_summarization_to_word(directory_path + "Indonesia/", 'docs')
# papers_summarization_to_word(directory_path + "Nigeria/", 'docs')
# papers_summarization_to_word(directory_path + "South Africa/", 'docs')
# Out:
# I will read 13 papers
# The paper CCDR Colombia 2023 WB.pdf is being reading
# The paper CCDR Colombia 2023 WB_short.pdf is being reading
# The paper Colombia_Report_Formatted_Updated_Climate_Strategies_FEDESARROLLO.pdf is being reading
# The paper Day 1_Session 4_b_PMI Colombia Just Transition_ by Marco Murcia_Colombia_0.pdf is being reading
# The paper DIAGNÓSTICOS, PROPUESTAS DE ABORDAJE PARA TRANSICION JUSTA EN COLOMBIA - DIC2020.pdf is being reading
# The paper diseño_HojaRutaTransicionEnergeticaJustaColombia_gob_Petro.pdf is being reading
# The paper Hoja de ruta_ Col_ para la transformacion energetica y modernizacion de la industria.pdf is being reading
# The paper impactos sociales energia eloica guajira.pdf is being reading
# The paper Incorporating-just-transition-strategies-into-developing-countries-NDCs-and-Covid-19-respons.pdf is being reading
# The paper NDC actualizada de Colombia.pdf is being reading
# ...

# %% [markdown]
# # Ejemplo Kristof

# %%
# Specify the directory path where your PDF files are located
directory_path = './Papers American Economic Review/Paper 2 - K De Witte/'

papers_summarization_to_word(directory_path, 'docs')
# Out:
# I will read 8 papers
# The paper cherchye2019.pdf is being reading
# The paper dewitte2013.pdf is being reading
# The paper dewitte2017.pdf is being reading
# The paper Interventions in higher education and their effect on student success a meta analysis.pdf is being reading
# The paper maldonado2021.pdf is being reading
# The paper Manuscript Coeducational.21.12.2022_toDan - Copy.pdf is being reading
# The paper mazrekaj-et-al-2020-school-outcomes-of-children-raised-by-same-sex-parents-evidence-from-administrative-panel-data.pdf is being reading
# The paper mazrekaj2019.pdf is being reading
# I got 8 summarization of 8 papers
# The summarization of articles had finished successfully.

# %%
print(Respuesta[0])
# Out:
# {
# 1. Paper title: Environmental Regulation and Green Skills: An Empirical Exploration
# ...

# %% [markdown]
# # Ejemplo Inicial Test 0

# %%
import os

# Specify the directory path where your PDF files are located
directory_path = 'Papers American Economic Review/Paper 1 - Natural-Resource-Booms-Human-Capital/Literature/'
papers_summarization_to_word(directory_path)

# List all files in the directory
all_files = os.listdir(directory_path)

# Filter the PDF files
pdf_files = [file for file in all_files if file.endswith('.pdf')]

print("I will read {} papers".format(len(pdf_files)) )

Respuesta=[]
# Print the list of PDF files
for pdf_file in pdf_files:
    paragraphs = extract_cleaned_paragraphs('./'+directory_path+pdf_file)
    texto  = paragraphs[0]
    promt = promt_desing(texto)
    response = model.predict(promt ,    **parameters )
    Respuesta.append(response.text )

print("I got {} summarization of {} papers".format(len(Respuesta), len(pdf_files)) )
# Out:
# ['Adukia 2020.pdf',
#  'Andrews 2016.pdf',
#  'Atkin 2016.pdf',
#  'Black 2005.pdf',
#  'Charles 2018.pdf',
#  'emery 2012.pdf',
#  'Morissette 2015.pdf',
#  'Mountjoy 2022.pdf',
#  'Zimmerman 2014.pdf']

# %%
len(Respuesta)
# Out:
# 9

# %%
print(""" \n1. Paper title: Educational Investment Responses to Economic Opportunity: Evidence from Indian Road Construction\n2. Abstract summary: This paper examines the impact of new roads on educational choices in India. Using a combination of human and machine fuzzy matching, the authors linked DISE data to administrative data from the national rural road construction program. The result is a panel of 300,000 villages across India. The authors find that children stay in school longer and perform better on standardized exams after a new road is built. Heterogeneity in treatment effects supports a standard human capital investment model: enrollment increases most when nearby labor markets offer high returns to education and least when they imply high opportunity costs of schooling.\n3. Authors: Anjali Adukia, Sam Asher, Paul Novosad\n4. Journal: Not provided in the given text.\n5. Number of participants: 300,000 villages across India\n6. Population characteristics: Children in rural India\n7. Intervention: New roads built under India's ﬂagship road construction program\n8. Main findings: Children stay in school longer and perform better on standardized exams after a new road is built. Heterogeneity in treatment effects supports a standard human capital investment model: enrollment increases most when nearby labor markets offer high returns to education and least when they imply high opportunity costs of schooling.\n9. Outcomes measured: Enrollment and standardized exam scores\n10. Design of the Study: Panel regression with village and state-time fixed effects", '', '', '{\n1. Paper title: Tight Labor Markets and the Demand for Education: Evidence from the Coal Boom and Bust\n2. Abstract summary: This paper studies the effect of the Appalachian coal boom and bust on high school enrollments. During the 1970s, a boom in the coal industry increased earnings of high school graduates relative to those of dropouts. The authors find that dropout rates increased in coal-producing counties in Kentucky and Pennsylvania in the 1970s and declined in the 1980s. The estimates indicate that a long-term 10% increase in the earnings of low-skilled workers could decrease school enrollment rates by as much as 5-7%.\n3. Authors: Dan A. Black, Terra G. McKinnish and Seth G. Sanders\n4. Journal: Industrial and Labor Relations Review\n5. Number of participants: Not provided in the given text.\n6. Population characteristics: High school dropouts in coal-producing counties in Kentucky and Pennsylvania.\n7. Intervention: The coal boom and bust\n8. Main findings: The authors find that dropout rates increased in coal-producing counties in Kentucky and Pennsylvania in the 1970s and declined in the 1980s. The estimates indicate that a long-term 10% increase in the earnings of low-skilled workers could decrease school enrollment rates by as much as 5-7%.\n9. Outcomes measured: High school dropout rates\n10. Design of the Study: Not provided in the given text.\n}', '', '{\n1. Paper title: Long-term consequences of natural resource booms for human capital accumulation\n2. Abstract summary: This paper examines the long-term effects of the Alberta 1973 to 1981 oil boom on the human capital investments and productivity for Alberta birth cohorts that were of normal schooling ages before, during, and after the oil boom. The findings suggest that resource booms may change the timing of schooling but they do not reduce the total accumulation of human capital.\n3. Authors: J. C. Herbert Emery, Ana Ferrer, and David Green\n4. Journal: ILR Review\n5. Number of participants: Alberta birth cohorts that were of normal schooling ages before, during, and after the oil boom\n6. Population characteristics: Alberta birth cohorts\n7. Intervention: Alberta 1973 to 1981 oil boom\n8. Main findings: Resource booms may change the timing of schooling but they do not reduce the total accumulation of human capital.\n9. Outcomes measured: Human capital investments and productivity\n10. Design of the Study: Not provided in the given text.\n}', "{\n1. Paper title: Wages, Youth Employment, and School Enrollment: Recent Evidence from Increases in World Oil Prices\n2. Abstract summary: This study uses variation in youth wages induced by increases in world oil prices to estimate the elasticity of young men's labor market participation and school enrollment with respect to after-tax wages. The main finding is that in the aggregate, increased wages have a dual impact: They tend to reduce—at least temporarily—young men's full-time university enrollment rates but bring (back) into the labor market some young men who were neither enrolled in school nor employed. Contrary to previous research, the study finds little evidence that young men with no high school diploma now leave school in response to increased wages.\n3. Authors: René Morissette, Ping Ching Winnie Chan, Yuqian Lu\n4. Journal: Journal of Human Resources\n5. Number of participants: Not specified in the given text.\n6. Population characteristics: Young men in Canada\n7. Intervention: Increases in world oil prices\n8. Main findings: The study finds that increased wages have a dual impact: They tend to reduce—at least temporarily—young men's full-time university enrollment rates but bring (back) into the labor market some young men who were neither enrolled in school nor employed. Contrary to previous research, the study finds little evidence that young men with no high school diploma now leave school in response to increased wages.\n9. Outcomes measured: Youth employment, school enrollment, likelihood of being neither enrolled in school nor employed, and likelihood of being both enrolled and employed.\n10. Design of the Study: The study uses a natural experiment approach to estimate the causal impact of wages on young men's employment and school enrollment decisions.", '1. Paper title: Community Colleges and Upward Mobility\n2. Abstract summary: This paper examines the causal effects of 2-year college access on educational attainment and earnings. Using a new instrumental variables approach that identifies causal effects along multiple treatment margins, I find that 2-year colleges provide significant value-added for students who would not have attended college otherwise, but negative impacts on students diverted from immediate 4-year entry.\n3. Authors: Jack Mountjoy\n4. Journal: NBER Working Paper Series\n5. Number of participants: 1.6 million first-time college entrants in Texas\n6. Population characteristics: High school graduates in Texas\n7. Intervention: Access to 2-year community colleges\n8. Main findings: 2-year colleges provide significant value-added for students who would not have attended college otherwise, but negative impacts on students diverted from immediate 4-year entry.\n9. Outcomes measured: Educational attainment and earnings\n10. Design of the Study: Instrumental variables approach',""")
# Out:
#
# 1. Paper title: Educational Investment Responses to Economic Opportunity: Evidence from Indian Road Construction
# 2. Abstract summary: This paper examines the impact of new roads on educational choices in India. Using a combination of human and machine fuzzy matching, the authors linked DISE data to administrative data from the national rural road construction program. The result is a panel of 300,000 villages across India. The authors find that children stay in school longer and perform better on standardized exams after a new road is built. Heterogeneity in treatment effects supports a standard human capital investment model: enrollment increases most when nearby labor markets offer high returns to education and least when they imply high opportunity costs of schooling.
# 3. Authors: Anjali Adukia, Sam Asher, Paul Novosad
# 4. Journal: Not provided in the given text.
# 5. Number of participants: 300,000 villages across India
# ...

# %% [markdown]
# # Creacion de Slides

# %%
# !pip install python-pptx

# %%
from pptx import Presentation
from pptx.util import Pt


# Font size variables 
title_font_size = 28
bullet_font_size = 14

# Create a blank presentation
prs = Presentation()
# Add the first slide

title_slide_layout = prs.slide_layouts[0] 
slide = prs.slides.add_slide(title_slide_layout)

title = slide.shapes.title  
title.text = "Summary Literature of the Folder" +

# %%
from pptx import Presentation
from pptx.util import Pt

# for
Paper_title = 'Educational Investment Responses to Economic Opportunity: Evidence from Indian Road Construction'

 

# First slide
slide = prs.slides.add_slide(prs.slide_layouts[1])

title_shape = slide.shapes.title
title = "Paper Summary" 
title_shape.text = title

# Set title font size
title_shape.text_frame.paragraphs[0].font.size = Pt(title_font_size) 

bullet_points1 = slide.shapes.placeholders[1]

points1 = """
- 1. Paper title: Educational Investment Responses to Economic Opportunity: Evidence from Indian Road Construction 

- 3. Authors: Anjali Adukia, Sam Asher, Paul Novosad

- 5. Number of participants: 300,000 villages across India

- 7. Intervention: New roads built under India's flagship road construction program 
"""

bullet_points1.text = points1  

# Set bullet points font size
bullet_points1.text_frame.paragraphs[0].font.size = Pt(bullet_font_size)


# Second slide
slide = prs.slides.add_slide(prs.slide_layouts[1]) 

title_shape = slide.shapes.title
title = "Paper Summary (Cont.)"
title_shape.text = title

# Set title font size
title_shape.text_frame.paragraphs[0].font.size = Pt(title_font_size)

bullet_points2 = slide.shapes.placeholders[1]

points2 = """
- 2. Abstract summary: This paper examines the impact of new roads on educational choices in India. Using a combination of human and machine fuzzy matching, the authors linked DISE data to administrative data from the national rural road construction program. The result is a panel of 300,000 villages across India. The authors find that children stay in school longer and perform better on standardized exams after a new road is built. Heterogeneity in treatment effects supports a standard human capital investment model: enrollment increases most when nearby labor markets offer high returns to education and least when they imply high opportunity costs of schooling.

- 4. Journal: Not provided in the given text.  

- 6. Population characteristics: Children in rural India

- 8. Main findings: Children stay in school longer and perform better on standardized exams after a new road is built. Heterogeneity in treatment effects supports a standard human capital investment model: enrollment increases most when nearby labor markets offer high returns to education and least when they imply high opportunity costs of schooling.

- 9. Outcomes measured: Enrollment and standardized exam scores  

- 10. Design of the Study: Panel regression with village and state-time fixed effects
"""

bullet_points2.text = points2

# Set bullet points font size
bullet_points2.text_frame.paragraphs[0].font.size = Pt(bullet_font_size) 

prs.save('test.pptx')

# %%
prs.save('test.pptx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 title_shape.font.size = Pt(28)
#       2 bullet_points.font.size = Pt(18)
#       3 prs.save('test.pptx')
#
# AttributeError: 'SlidePlaceholder' object has no attribute 'font'

# %%
parameters = {
"temperature":0,0
"max_output_tokens": 1024,
"top_p": 0.8,
"top_k": 40
}
def paper_title(model, first_text, parameters):
    response = model.predict(
    """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
        Paper title
        example 1.
        input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
        output_text = Paper title: Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial.
        input_text:  """  + first_text + """
        output_text =
        """  ,
            **parameters
        )
    return  str(response.text).replace("Paper title: ","").replace("{","").replace("}","")

def paper_author(model, first_text, parameters):
    
    response = model.predict(
    """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
        1. Authors
        example 1.
        input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
        output_text = Authors: B. Symon, J. Marley, A. Martin, E. Norman  
        input_text:  """  + first_text + """
        output_text =
        """  ,
            **parameters
        )
    return  str(response.text).replace("Authors: ","").replace("{","").replace("}","")

def paper_year(model, first_text, parameters):
    response = model.predict(
    """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
        1. Year of paper

        example 1.
        input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
        output_text = Year: 2005 
        input_text:  """  + first_text + """
        output_text =
        """  ,
            **parameters
        )
    return  str(response.text).replace("Year: ","").replace("{","").replace("}","")

def paper_journal(model, first_text, parameters):

    response = model.predict(
    """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
        1. Journal 
        example 1.
        input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
        output_text = Journal: Medical Journal of Australia.
        input_text:  """  + first_text + """
        output_text =
        """  ,
            **parameters
        )
    return  str(response.text).replace("Journal: ","").replace("{","").replace("}","")
summary_paper = paper_title(model, paragraphs[0], parameters)
# Out:
#   Cell In[53], line 2
#     "temperature":0,0
#                     ^
# SyntaxError: ':' expected after dictionary key

# %%
bibtex_entry_template = """
@article{your-paper-key,
    title = {REPLACE_TITLE},
    abstract = {REPLACE_ABSTRACT},
    author = {REPLACE_AUTHOR},
    journal = {REPLACE_JOURNAL},
    year = {REPLACE_YEAR},
    influential_citations = {REPLACE_INFLUENTIAL_CITATIONS},
    sjr = {REPLACE_SJR},
    participants = {REPLACE_PARTICIPANTS},
    population_characteristics = {REPLACE_POPULATION_CHARACTERISTICS},
    age = {REPLACE_AGE},
    intervention = {REPLACE_INTERVENTION},
    detailed_abstract = {REPLACE_DETAILED_ABSTRACT},
    main_findings = {REPLACE_MAIN_FINDINGS},
    outcomes_measured = {REPLACE_OUTCOMES_MEASURED},
    study_design = {REPLACE_STUDY_DESIGN},
    preregistration = {REPLACE_PREREGISTRATION},
    multiple_comparisons = {REPLACE_MULTIPLE_COMPARISONS},
    intent_to_treat = {REPLACE_INTENT_TO_TREAT},
}
"""

# Replace the placeholders for specific fields with function results
bibtex_entry = bibtex_entry_template.replace(
    "REPLACE_TITLE", paper_title(model, first_text, parameters)
).replace(
    "REPLACE_AUTHOR", paper_author(model, first_text, parameters)
).replace(
    "REPLACE_JOURNAL", paper_journal(model, first_text, parameters)
).replace(
    "REPLACE_YEAR", paper_year(model, first_text, parameters)
)

print(bibtex_entry)
# Out:
# @article{your-paper-key,
#     title = {Black Gold and Dull Minds: The Impact of Hydrocarbon Exploration Announcements on Education in Colombia},
#     abstract = {REPLACE_ABSTRACT},
#     author = {Jaime Polanco-Jim´enez, Christian Posso},
#     journal = {Journal of Development Economics},
#     year = {2023},
#     influential_citations = {REPLACE_INFLUENTIAL_CITATIONS},
#     sjr = {REPLACE_SJR},
#     participants = {REPLACE_PARTICIPANTS},
#     population_characteristics = {REPLACE_POPULATION_CHARACTERISTICS},
#     age = {REPLACE_AGE},
#     intervention = {REPLACE_INTERVENTION},
#     detailed_abstract = {REPLACE_DETAILED_ABSTRACT},
#     main_findings = {REPLACE_MAIN_FINDINGS},
#     outcomes_measured = {REPLACE_OUTCOMES_MEASURED},
#     study_design = {REPLACE_STUDY_DESIGN},
#     preregistration = {REPLACE_PREREGISTRATION},
#     multiple_comparisons = {REPLACE_MULTIPLE_COMPARISONS},
#     intent_to_treat = {REPLACE_INTENT_TO_TREAT},
# }

# %%
# !pip install shapely<2.0.0

def paper_title(model, first_text):
    parameters = {
    "temperature": 0.1,
    "max_output_tokens": 1024,
    "top_p": 0.8,
    "top_k": 40
    }
    response = model.predict(
    """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
        1. Paper title
        2. Authors
        3. Year of paper
        4. Journal 
        example 1.
        input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
        output_text = Paper title: Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial.
        Authors: B. Symon, J. Marley, A. Martin, E. Norman  
        Year of paper: 2005
        Journal: Medical Journal of Australia.
        input_text:  """  + first_text + """
        output_text =
        """  ,
            **parameters
        )
    return  response.text

def paper_abstract(model, first_text):
    parameters = {
    "temperature": 0.1,
    "max_output_tokens": 256,
    "top_p": 0.8,
    "top_k": 40
    }
    response = model.predict(
    """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
        1. Abstract summary
        2. Main findings
        example 1.
        input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
        output_text = Abstract summary: A behavior modification program taught to parents in a single visit to a trained nurse improved sleep performance in newborn infants.
        Main findings: • The behaviour modification program was effective in improving sleep performance in newborn infants.
• The intervention was associated with a significant reduction in the number of night awakenings and an increase in the total sleep duration.
• The effects of the intervention were sustained at the 3-month follow-up.
        
        input_text:  """  + first_text + """
        output_text =
        """  ,
            **parameters
        )
    return  response.text

def paper_findings(model, text):
    parameters = {
    "temperature": 0.1,
    "max_output_tokens": 1000,
    "top_p": 0.8,
    "top_k": 40
    }
    response = model.predict(
    """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
        Main findings
        example 1.
        input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
        output_text = Main findings: • The behaviour modification program was effective in improving sleep performance in newborn infants.
• The intervention was associated with a significant reduction in the number of night awakenings and an increase in the total sleep duration.
• The effects of the intervention were sustained at the 3-month follow-up.
        
        input_text:  """  + text[0] + """
        output_text =
        """  ,
            **parameters
        )
    first_resuult = response.text
    print(first_resuult)
    for section in text[0]:
        response = model.predict( """
        Use the context below to complete or give more extensive information about the results of the investigation. If the context doesn't add information to the main results then responce ' '. Don't invent or make up things.
               
        Example 1. 
        context: "Main findings: 
        • The behaviour modification program was effective in improving sleep performance in newborn infants.
        • The intervention was associated with a significant reduction in the number of night awakenings and an increase in the total sleep duration.
        • The effects of the intervention were sustained at the 3-month follow-up."
        input_text: "ithin 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal intensive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a reference point based on clinical experience."
        output_text: "Main findings: 
        • The behaviour modification program was effective in improving sleep performance in newborn infants.
        • The intervention was associated with a significant reduction in the number of night awakenings and an increase in the total sleep duration.
        • The effects of the intervention were sustained at the 3-month follow-up.
        • 30% of sample increase the sleeping time to 15 hours. END
        Example 2. 
        context: "Main findings: 
        • The behaviour modification program was effective in improving sleep performance in newborn infants.
        • The intervention was associated with a significant reduction in the number of night awakenings and an increase in the total sleep duration.
        • The effects of the intervention were sustained at the 3-month follow-up.
        • 30% of sample increase the sleeping time to 15 hours. "
        input_text: "This study utilizes a combination of three primary datasets to investigate the impact of hydrocarbon exploration announcements on school dropout rates in Colombia. The analysis relies on the Student Enrollment System in Colombia (SIMAT) data, covering the period from 2012 to 2020. This dataset offers valuable insights into student enrollment trends and characteristics, particularly for schools located near areas undergoing exploration and production (E\&P) activities. Additionally, the integration of the E\&P contracts in Colombia dataset, obtained from the National Hydrocarbons Agency (ANH), enables the examination of the relationship between contract signing dates and dropout rates during the preliminary phase. Furthermore, the georeferenced base of school locations provided by the National Administrative Department of Statistics (DANE) allows for spatial analysis and the investigation of the spatial distribution of schools in relation to E\&P contract areas. The comprehensive database employed in this study comprises an extensive range of columns that contain valuable information essential for understanding various aspects of the educational landscape. Notably, it provides insights into school dropout rates, gender distribution, and the total number of students. Additionally, it offers a comprehensive overview of enrollment status within the same school and sheds light on migration and immigration patterns. The inclusion of demographic data, such as socioeconomic stratum, age, subsidy type, and geographic details related to school campuses, further enriches the dataset. (See dictionary of the data based"
        output_text: "Main findings: 
        • The behaviour modification program was effective in improving sleep performance in newborn infants.
        • The intervention was associated with a significant reduction in the number of night awakenings and an increase in the total sleep duration.
        • The effects of the intervention were sustained at the 3-month follow-up.
        • 30% of sample increase the sleeping time to 15 hours.  " END
        
        context = ["""+first_resuult +"""]
        input_text: """+ section  + """ \n
        output_text: """,
                                 **parameters)
        first_resuult = response.text                         
        print(first_resuult)
    # return  first_resuult

# %%
import vertexai
from vertexai.language_models import TextGenerationModel

vertexai.init(project="ph-jabri", location="us-central1")
parameters = {
    "temperature": 0.1,
    "max_output_tokens": 1024,
    "top_p": 0.8,
    "top_k": 40
}
model = TextGenerationModel.from_pretrained("text-bison@001")
# response = model.predict(
#     """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
#         1. Paper title
#         2. Authors
#         3. Year

# example 1.
# input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
# output_text = 1. Paper title: Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial.

# input_text:  """  + paragraphs[0] + """
# output_text =
# """  ,
#     **parameters
# )
# Article_summarization = response.text

# %%
paper_findings(model, paragraphs)
# Out:
# 2. Main findings
#         We find that the announcement of hydrocarbon exploration has a significant impact on dropout rates. Specifically, we find that the announcement of hydrocarbon exploration leads to a reduction in dropout rates among elementary school pupils, with a more pronounced effect observed among girls. However, we find that the announcement of hydrocarbon exploration leads to an increase in dropout rates among secondary school pupils.
# "2. Main findings
#         We find that the announcement of hydrocarbon exploration has a significant impact on dropout rates. Specifically, we find that the announcement of hydrocarbon exploration leads to a reduction in dropout rates among elementary school pupils, with a more pronounced effect observed among girls. However, we find that the announcement of hydrocarbon exploration leads to an increase in dropout rates among secondary school pupils.
#
# ...

# %%
paper = paper_title(model, paragraphs[0])
paper+= '\n' + paper_goal_motivation(model, paragraphs[0])
print(paper)

# %%
import vertexai
from vertexai.language_models import TextGenerationModel

vertexai.init(project="ph-jabri", location="us-central1")
parameters = {
    "temperature": 0.2,
    "max_output_tokens": 1024,
    "top_p": 0.8,
    "top_k": 40
}
model = TextGenerationModel.from_pretrained("text-bison@001")
response = model.predict(
    """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
1. Paper title
2. Abstract summary
3. Authors
4. Journal
5. Influential citations
6. Scimago Journal Rank
7. Number of participants
8. Population characteristics
9. Age
10. Intervention
11. Detailed abstract summary
12. Main findings
13. Outcomes measured
14. Detailed study design
15. Preregistration
16. Multiple comparisons
17. Intent to treat
example 1.
input_text: \"PUBLISHED VERSION Symon, Brian Gerald; Marley, John Ernest; Martin, Alfred James; Norman, Emily R. Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial Medical Journal of Australia, 2005; 182 (5):215-218 This article is available from the Medical Journal of Australia at: https://www.mja.com.au/journal/2005/182/5/effect-consultation-teaching-behaviour-modification- sleep-performance-infants PERMISSIONS This document has been archived with permission from the editor of the Medical Journal of Australia, ABSTRACT Objective: To evaluate the effect of a behaviour modification program, taught to parents in a single visit to a trained nurse, in improving sleep performance in newborn infants. Design: Randomised controlled trial. Setting and participants: 268 families with normal newborn infants in the community, recruited between October 1996 and March 1997 from birth notices published in a South Australian daily newspaper. Intervention: A 45-minute consultation with a nurse 2–3 weeks after the birth, including a tutorial discussion on normal sleep patterns in newborn infants, supported by retained written material and, for infants with weight gain < 30 g daily, referral to their usual postnatal care provider. Main outcome measures: Hours of daytime sleep (0600–1800), night sleep (1800–0600) and total sleep per 24 h; and number of daily records with total sleep (cid:1) 15 h per 24 h, assessed by 7-day sleep diary at ages 6 and 12 weeks. Results: 268 families returned at least one sleep diary (137/171 intervention, 131/175 control), recording 3273 days. Two intervention infants were referred for low weight gain. Total sleep time was 15 h or more per 24 h on 62% of recorded days in the intervention group, compared with 36% in the control group (P < 0.001). At 6 weeks of age, intervention infants slept a mean 1.3 h per day more than control infants (95% CI, 0.95– 1.65), comprising a mean 0.5 h more night sleep (95% CI, 0.32–0.69) and 0.8 h more daytime sleep (95% CI, 0.56–1.07). At 12 weeks, intervention infants slept a mean 1.2 h per day more (95% CI, 0.94–2.14), comprising 0.64 h more night sleep (95% CI, 0.19–0.89) and 0.58 h more daytime sleep (95% CI, 0.39–1.03). There was no significant difference in crying time between the groups. Conclusions: A single consultation supported by written material in the first 3 weeks of a child’s life improves sleep performance at 6 weeks of age. This improvement is maintained at 3 months. METHODS Study population Families were recruited from birth notifica- tions published in the Adelaide Advertiser, the only South Australian daily newspaper, between October 1996 and March 1997. Contact details were obtained from the tele- phone directory. Parents were contacted by telephone within 2 weeks of their child’s birth and invited to participate in a study of sleep performance in healthy newborns. Those who agreed to participate were asked about MJA 2005; 182: 215–218 the baby’s health and medical history. Those who refused were not formally asked for their reasons. Inclusion criteria included delivery at 36– 42 weeks’ gestation, English-speaking mother, telephone in the home, and the mother intending to provide full-time care to her infant for at least the first 12 weeks after birth. A criterion for exclusion was admission of the infant to a neonatal inten- sive care unit for illness within the first 2 weeks after birth. Parents who agreed to participate were mailed a consent form. A sample size of 130 per group was determined, based on the minimum number of participants required to detect a predicted effect of a 30% increase in the proportion of children achieving 15 hours of sleep per 24 hours with a power of 90%.14 The period of 15 hours was chosen empirically as a refer- ence point based on clinical experience. MJA • Volume 182 Number 5 • 7 March 2005 215 Adelaide, SA. Brian G Symon, MD, General Practitioner. The University of Newcastle, Newcastle, NSW. John E Marley, MD, Pro Vice-Chancellor, Health. Adelaide Women\'s and Children\'s Hospital, Adelaide, SA A James Martin, MD, Head of Respiratory Medicine; Emily R Norman, MB BS, Intern. Reprints will not be available from the authors. Correspondence: Dr Brian G Symon, 84 Shipsters Road, Kensington Park, SA 5068. brian.symon@adelaide.edu.au R ES E A R C H 1 Advice about infant sleeping given to parents in the intervention group Parents were informed that: • Infant sleep is cyclical, with repeated episodes of arousal within a block of sleep. • Environmental factors or “cues of sleep” influence transitions to sleep and can be learned, altered and relearned. • Thus, sleep achievement is a “learned” skill. • Fatigue interferes with the performance of learned skills (ie, sleep achievement), and tearfulness in a well-fed neonate may reflect fatigue rather than pain. child was aged 6 weeks and again at 12 weeks; recording began on the first day after the child turned 6 weeks and then 12 weeks. The sleep diary allowed every 10- minute period over 24 hours to be scored for the child being asleep, awake, feeding or crying. Parents recorded data when conven- ient. • Parent-independent sleep cues are the most useful for developing “independent sleep skills”. 5-year review Parents were encouraged to minimise handling at the time of sleep achievement. It was recommended that parents focus on: • Allowing an infant to be in a “parent-independent” position at initial sleep achievement. • Regarding crying at sleep initiation as being due to tiredness and best handled by minimal parental response. • Leaving a settling infant for a minimum of 5 minutes before responding if the infant is crying; this time interval is to be extended by 5 minutes for each additional return visit to the child. 2 Flow of participants in the study of sleep performance 1001 families contacted (cid:127)\"
 output_text = {Paper title: Effect of a consultation teaching behaviour modification on sleep performance in infants: a randomised controlled trial
Abstract summary: A behavior modification program taught to parents in a single visit to a trained nurse improved sleep performance in newborn infants.
Authors: B. Symon, J. Marley, A. Martin, E. Norman
Journal: Medical Journal of Australia
Number of participants: at least 260
Population characteristics: newborn infants
 
Intervention: an intervention group
Detailed abstract summary
Main findings: \"• The behaviour modification program was effective in improving sleep performance in newborn infants.
• The intervention was associated with a significant reduction in the number of night awakenings and an increase in the total sleep duration.
• The effects of the intervention were sustained at the 3-month follow-up.\"
Outcomes measured: •Sleep Performance In Newborn Infants
Detailed study design: randomized controlled trial
Preregistration
Multiple comparisons
Intent to treat
 
input_text: \' {}\'
output_text =
""".format(paragraphs[0]) ,
    **parameters
)
print(f"Response from Model: {response.text}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 53
#       5 parameters = {
#       6     "temperature": 0.2,
#       7     "max_output_tokens": 1024,
#       8     "top_p": 0.8,
#       9     "top_k": 40
#      10 }
#      11 model = TextGenerationModel.from_pretrained("text-bison@001")
#      12 response = model.predict(
#      13     """Use the following pieces of context to summarize the article, Don't invent or make up things. I need the next point:
#      14 1. Paper title
#      15 2. Abstract summary
#      16 3. Authors
#      17 4. Journal
#      18 5. Influential citations
#      19 6. Scimago Journal Rank
#      20 7. Number of participants
#      21 8. Population characteristics
#      22 9. Age
#      23 10. Intervention
#      24 11. Detailed abstract summary
#      25 12. Main findings
#      26 13. Outcomes measured
# ...
